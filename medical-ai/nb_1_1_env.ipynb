# %% [markdown]
# 📒 [NB 1-1] 다양한 의료 데이터 불러오기 및 구조 파악
# 1. 환경 설정 및 패키지 설치
# 데이터 분석의 핵심 라이브러리인 Pandas와 엑셀 파일을 다루기 위한 openpyxl을 설치한다.

# %%
# 필수 라이브러리 설치 (코랩 환경에서는 이미 설치되어 있을 수 있으나 확인 차 실행한다)
# !pip install pandas numpy openpyxl

import pandas as pd
import numpy as np
import os

print("라이브러리 로드 완료.")
# Out:
# ...
# 라이브러리 로드 완료.

# %% [markdown]
# 2. 가상 데이터 생성 (파일 만들기)
# 실습을 위해 CSV, Excel, JSON 포맷의 가상 의료 데이터를 생성한다. 실제 현장에서는 병원 서버나 공공데이터 포털에서 다운로드한 파일을 사용하게 된다.

# %%
# 1. 가상의 환자 데이터 생성
data = {
    'Patient_ID': ['P001', 'P002', 'P003', 'P004', 'P005'],
    'Name': ['Kim', 'Lee', 'Park', 'Choi', 'Jung'],
    'Age': [25, 47, 68, 34, 82],
    'Gender': ['M', 'F', 'M', 'F', 'M'],
    'Diagnosis': ['Normal', 'Diabetes', 'Hypertension', 'Normal', 'Cancer'],
    'HbA1c': [5.2, 7.8, 6.1, 5.4, 6.5]  # 당화혈색소 수치
}
df_dummy = pd.DataFrame(data)

# 2. 다양한 포맷으로 저장 (현재 폴더에 파일이 생성된다)
df_dummy.to_csv('medical_data.csv', index=False)
df_dummy.to_excel('medical_data.xlsx', index=False)
df_dummy.to_json('medical_data.json', orient='records')

print("실습용 가상 파일 생성 완료: csv, xlsx, json")
# Out:
# 실습용 가상 파일 생성 완료: csv, xlsx, json

# %% [markdown]
# 3. 데이터 불러오기 (Load)
# 저장된 파일을 Pandas를 이용해 DataFrame으로 불러온다. 확장자에 따라 사용하는 함수가 다르다.

# %%
# CSV 파일 읽기 (Comma Separated Values) - 가장 흔한 포맷
df_csv = pd.read_csv('medical_data.csv')
print("--- CSV Load ---")
display(df_csv.head(2))

# Excel 파일 읽기
df_excel = pd.read_excel('medical_data.xlsx')
print("\n--- Excel Load ---")
display(df_excel.head(2))

# JSON 파일 읽기 (웹/앱 연동 데이터에 주로 사용)
df_json = pd.read_json('medical_data.json')
print("\n--- JSON Load ---")
display(df_json.head(2))
# Out:
# --- CSV Load ---
#   Patient_ID Name  Age Gender Diagnosis  HbA1c
# 0       P001  Kim   25      M    Normal    5.2
# 1       P002  Lee   47      F  Diabetes    7.8
# --- Excel Load ---
#   Patient_ID Name  Age Gender Diagnosis  HbA1c
# 0       P001  Kim   25      M    Normal    5.2
# 1       P002  Lee   47      F  Diabetes    7.8
# --- JSON Load ---
#   Patient_ID Name  Age Gender Diagnosis  HbA1c
# 0       P001  Kim   25      M    Normal    5.2
# 1       P002  Lee   47      F  Diabetes    7.8

# %% [markdown]
# 4. 데이터 구조 파악하기
# 데이터를 불러온 직후에는 반드시 데이터의 '생김새'를 확인해야 한다. 행/열의 개수, 데이터 타입, 결측치 여부 등을 체크한다.

# %%
# 사용할 데이터 지정
df = df_csv

# 1. 데이터의 크기 확인 (행, 열)
print(f"데이터 크기 (Shape): {df.shape}")  # (5, 6) 출력 예상

# 2. 데이터의 전반적인 정보 확인 (타입, 결측치, 메모리)
print("\n[데이터 정보 요약]")
df.info()

# 3. 수치형 데이터의 기초 통계량 확인
print("\n[기초 통계량]")
display(df.describe())

# 4. 범주형 데이터의 분포 확인 (Object 타입)
print("\n[진단명(Diagnosis) 분포]")
print(df['Diagnosis'].value_counts())
# Out:
# 데이터 크기 (Shape): (5, 6)
#
# [데이터 정보 요약]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Patient_ID  5 non-null      object
#  1   Name        5 non-null      object
#  2   Age         5 non-null      int64
#  3   Gender      5 non-null      object
#  4   Diagnosis   5 non-null      object
#  5   HbA1c       5 non-null      float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 372.0+ bytes
#
# [기초 통계량]
#              Age     HbA1c
# count   5.000000  5.000000
# mean   51.200000  6.200000
# std    23.615673  1.036822
# min    25.000000  5.200000
# 25%    34.000000  5.400000
# 50%    47.000000  6.100000
# 75%    68.000000  6.500000
# max    82.000000  7.800000
# [진단명(Diagnosis) 분포]
# Diagnosis
# Normal          2
# Diabetes        1
# Hypertension    1
# Cancer          1
# Name: count, dtype: int64
